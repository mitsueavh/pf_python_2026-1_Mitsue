# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
f="../data/002_processed/2024.parquet"
esol= pd.read_parquet(f)
esol.describe()
# Out:
#           I_glo_Avg     I_dir_Avg     I_dif_Avg     WS_ms_Avg       WindDir  \
# count  52611.000000  52610.000000  52611.000000  52611.000000  52611.000000
# mean     256.594246    273.405908    119.619755      1.665913    214.128730
# std      347.129747    472.026507    314.344784      1.010401    110.703332
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.025000      0.000000      1.033000    134.000000
# 50%        3.880000     11.700000      2.613000      1.649000    216.800000
# 75%      519.450000    571.500000    136.200000      2.211000    327.800000
# max     1335.000000   7999.000000   7999.000000     11.170000    351.600000
#
#           AirTC_Avg            RH  CS106_PB_Avg
# count  52611.000000  52611.000000  52611.000000
# mean      24.781846     54.627791    893.822067
# std        5.075753     24.003624     89.071656
# min       11.060000      5.059000    483.774100
# ...

# %%
esol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52611 entries, 2023-07-01 00:00:00 to 2024-06-30 23:50:00
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   I_glo_Avg     52611 non-null  float64
#  1   I_dir_Avg     52610 non-null  float64
#  2   I_dif_Avg     52611 non-null  float64
#  3   WS_ms_Avg     52611 non-null  float64
#  4   WindDir       52611 non-null  float64
#  5   AirTC_Avg     52611 non-null  float64
#  6   RH            52611 non-null  float64
#  7   CS106_PB_Avg  52611 non-null  float64
# dtypes: float64(8)
# memory usage: 3.6 MB

# %%
esol.plot(subplots=True,figsize=(12,10));
